# %%
import pandas as pd #Just a scaling test, most of sklearn usage was applied directly into the model.
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
dfTest=pd.read_excel (r'C:\Users\Stefan\Desktop\UAX\IRONHACKK\Proyecto Final\Solución Regresión IH\data\regression_data.xls')
dfTest[['id','price']] = scaler.fit_transform(dfTest[['id','price']])
dfTest
# Out:
#              id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      0.720103 2014-10-13         3       1.00         1180      5650
# 1      0.647853 2014-12-09         3       2.25         2570      7242
# 2      0.568795 2015-02-25         2       1.00          770     10000
# 3      0.251157 2014-12-09         4       3.00         1960      5000
# 4      0.197333 2015-02-18         3       2.00         1680      8080
# ...         ...        ...       ...        ...          ...       ...
# 21592  0.026467 2014-05-21         3       2.50         1530      1131
# 21593  0.666639 2015-02-23         4       2.50         2310      5813
# 21594  0.153783 2014-06-23         2       0.75         1020      1350
# 21595  0.029327 2015-01-16         3       2.50         1600      2388
# 21596  0.153783 2014-10-15         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# ...
