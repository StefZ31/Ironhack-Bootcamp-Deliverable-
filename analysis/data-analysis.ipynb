# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_excel (r'C:\Users\Stefan\Desktop\UAX\IRONHACKK\Proyecto Final\Solución Regresión IH\data\regression_data.xls')
df
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520 2014-10-13         3       1.00         1180      5650
# 1      6414100192 2014-12-09         3       2.25         2570      7242
# 2      5631500400 2015-02-25         2       1.00          770     10000
# 3      2487200875 2014-12-09         4       3.00         1960      5000
# 4      1954400510 2015-02-18         3       2.00         1680      8080
# ...           ...        ...       ...        ...          ...       ...
# 21592   263000018 2014-05-21         3       2.50         1530      1131
# 21593  6600060120 2015-02-23         4       2.50         2310      5813
# 21594  1523300141 2014-06-23         2       0.75         1020      1350
# 21595   291310100 2015-01-16         3       2.50         1600      2388
# 21596  1523300157 2014-10-15         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(5)
# Out:
#            id       date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520 2014-10-13         3       1.00         1180      5650     1.0
# 1  6414100192 2014-12-09         3       2.25         2570      7242     2.0
# 2  5631500400 2015-02-25         2       1.00          770     10000     1.0
# 3  2487200875 2014-12-09         4       3.00         1960      5000     1.0
# 4  1954400510 2015-02-18         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
# ...

# %%
df.tail(5)
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 21592   263000018 2014-05-21         3       2.50         1530      1131
# 21593  6600060120 2015-02-23         4       2.50         2310      5813
# 21594  1523300141 2014-06-23         2       0.75         1020      1350
# 21595   291310100 2015-01-16         3       2.50         1600      2388
# 21596  1523300157 2014-10-15         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# 21592     3.0           0     0          3  ...        1530              0
# 21593     2.0           0     0          3  ...        2310              0
# 21594     2.0           0     0          3  ...        1020              0
# 21595     2.0           0     0          3  ...        1600              0
# 21596     2.0           0     0          3  ...        1020              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.shape
# Out:
# (21597, 21)

# %%
df.describe()
# Out:
#                  id      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  2.159700e+04
# mean   4.580474e+09      3.373200      2.115826   2080.321850  1.509941e+04
# std    2.876736e+09      0.926299      0.768984    918.106125  4.141264e+04
# min    1.000102e+06      1.000000      0.500000    370.000000  5.200000e+02
# 25%    2.123049e+09      3.000000      1.750000   1430.000000  5.040000e+03
# 50%    3.904930e+09      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    7.308900e+09      4.000000      2.500000   2550.000000  1.068500e+04
# max    9.900000e+09     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21597.000000  21597.000000  21597.000000  21597.000000  21597.000000
# mean       1.494096      0.007547      0.234292      3.409825      7.657915
# ...

# %%
df['id'].value_counts()
# Out:
# 795000620     3
# 8910500150    2
# 7409700215    2
# 1995200200    2
# 9211500620    2
#              ..
# 3649100387    1
# 2767603649    1
# 1446403617    1
# 5602000275    1
# 1523300157    1
# Name: id, Length: 21420, dtype: int64

# %%
df['price'].value_counts()
# Out:
# 450000    172
# 350000    172
# 550000    159
# 500000    152
# 425000    150
#          ...
# 278800      1
# 439888      1
# 354901      1
# 942000      1
# 402101      1
# Name: price, Length: 3622, dtype: int64

# %%
df['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      196
# 7       38
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=21597, step=1)

# %%
df.hist(bins=50, figsize=(15,15)) #shows us all the graphs
plt.show()

# %%
simpledf = df.drop(columns=['date','waterfront','lat','long','sqft_living','sqft_lot','view','yr_renovated','sqft_basement'])
simpledf #some columns which can be considered way less important have been removed
# Out:
#                id  bedrooms  bathrooms  floors  condition  grade  sqft_above  \
# 0      7129300520         3       1.00     1.0          3      7        1180
# 1      6414100192         3       2.25     2.0          3      7        2170
# 2      5631500400         2       1.00     1.0          3      6         770
# 3      2487200875         4       3.00     1.0          5      7        1050
# 4      1954400510         3       2.00     1.0          3      8        1680
# ...           ...       ...        ...     ...        ...    ...         ...
# 21592   263000018         3       2.50     3.0          3      8        1530
# 21593  6600060120         4       2.50     2.0          3      8        2310
# 21594  1523300141         2       0.75     2.0          3      7        1020
# 21595   291310100         3       2.50     2.0          3      8        1600
# 21596  1523300157         2       0.75     2.0          3      7        1020
#
# ...

# %%
#it's recommended to set an idex for our id, we have to confirm all values are unique first
simpledf['id'].is_unique
#it confirms that different ids have been repeated, so it's not ideal to sort via id, possibly some inputs have been repeated
# Out:
# False

# %%
indexsdf = simpledf.set_index('id')
indexsdf
# Out:
#             bedrooms  bathrooms  floors  condition  grade  sqft_above  \
# id
# 7129300520         3       1.00     1.0          3      7        1180
# 6414100192         3       2.25     2.0          3      7        2170
# 5631500400         2       1.00     1.0          3      6         770
# 2487200875         4       3.00     1.0          5      7        1050
# 1954400510         3       2.00     1.0          3      8        1680
# ...              ...        ...     ...        ...    ...         ...
# 263000018          3       2.50     3.0          3      8        1530
# 6600060120         4       2.50     2.0          3      8        2310
# 1523300141         2       0.75     2.0          3      7        1020
# 291310100          3       2.50     2.0          3      8        1600
# 1523300157         2       0.75     2.0          3      7        1020
#
#             yr_built  zipcode  sqft_living15  sqft_lot15   price
# id
# ...

# %%
indexsdf.index
# Out:
# Int64Index([7129300520, 6414100192, 5631500400, 2487200875, 1954400510,
#             7237550310, 1321400060, 2008000270, 2414600126, 3793500160,
#             ...
#             7852140040, 9834201367, 3448900210, 7936000429, 2997800021,
#              263000018, 6600060120, 1523300141,  291310100, 1523300157],
#            dtype='int64', name='id', length=21597)

# %%
#to access data we can use .loc, i.e we can try with id3810000455
indexsdf.loc[3810000455]
# Out:
# bedrooms              4.00
# bathrooms             2.25
# floors                1.00
# condition             3.00
# grade                 7.00
# sqft_above         1300.00
# yr_built           1960.00
# zipcode           98178.00
# sqft_living15      1990.00
# sqft_lot15         7383.00
# price            340000.00
# Name: 3810000455, dtype: float64

# %%
indexsdf.iloc[0] #or we can use .iloc to search according row number (0 being first row)
# Out:
# bedrooms              3.0
# bathrooms             1.0
# floors                1.0
# condition             3.0
# grade                 7.0
# sqft_above         1180.0
# yr_built           1955.0
# zipcode           98178.0
# sqft_living15      1340.0
# sqft_lot15         5650.0
# price            221900.0
# Name: 7129300520, dtype: float64

# %%
#another thing to consider is that many values are float types, instead of integers or strings, (i.e. some bathrooms have like 0.75)
indexsdf.dtypes #in this case bathrooms and floors need to be converted to that kind of data to make more sense, we'd basically have to round
# Out:
# bedrooms           int64
# bathrooms        float64
# floors           float64
# condition          int64
# grade              int64
# sqft_above         int64
# yr_built           int64
# zipcode            int64
# sqft_living15      int64
# sqft_lot15         int64
# price              int64
# dtype: object

# %%
simpledf=indexsdf.round(0)
simpledf #numbers are rounded now in those columns
# Out:
#             bedrooms  bathrooms  floors  condition  grade  sqft_above  \
# id
# 7129300520         3        1.0     1.0          3      7        1180
# 6414100192         3        2.0     2.0          3      7        2170
# 5631500400         2        1.0     1.0          3      6         770
# 2487200875         4        3.0     1.0          5      7        1050
# 1954400510         3        2.0     1.0          3      8        1680
# ...              ...        ...     ...        ...    ...         ...
# 263000018          3        2.0     3.0          3      8        1530
# 6600060120         4        2.0     2.0          3      8        2310
# 1523300141         2        1.0     2.0          3      7        1020
# 291310100          3        2.0     2.0          3      8        1600
# 1523300157         2        1.0     2.0          3      7        1020
#
#             yr_built  zipcode  sqft_living15  sqft_lot15   price
# id
# ...

# %%
finaldf=simpledf.astype(int) #now we change all values to integers to have clean values
finaldf.head(5)
# Out:
#             bedrooms  bathrooms  floors  condition  grade  sqft_above  \
# id
# 7129300520         3          1       1          3      7        1180
# 6414100192         3          2       2          3      7        2170
# 5631500400         2          1       1          3      6         770
# 2487200875         4          3       1          5      7        1050
# 1954400510         3          2       1          3      8        1680
#
#             yr_built  zipcode  sqft_living15  sqft_lot15   price
# id
# 7129300520      1955    98178           1340        5650  221900
# 6414100192      1951    98125           1690        7639  538000
# 5631500400      1933    98028           2720        8062  180000
# 2487200875      1965    98136           1360        5000  604000
# 1954400510      1987    98074           1800        7503  510000

# %%
finaldf.to_csv("CleanData.csv")

# %%
finaldf.to_excel("CleanData.xlsx")

# %%
#to proceed with a data-analysis we pretty much tried different dataset commands related on the original dataframe
#like head, tails, index, etc.
#then we start creating a cleaner dataframe that contains what we believe it's the exactly needed information (columns) dropping some columns
#for any house sale, kept essential info. Indexed the id to help during searches
#some of the values were assigned as floats and came with actual decimals when they were not supposed to 
#so we rounded those and then converted them from floats to integers


#note: some of the analysis is located in the model file, plotting, etc.
